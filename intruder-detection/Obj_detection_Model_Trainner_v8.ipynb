# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.0/879.0 kB 14.0 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ZlUVfqn6MYBeJ2RgMc86")
project = rf.workspace("daniel-ricardo-zapata-sanabria-yg1bj").project("t-shirts-detector")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to T-shirts-detector-1 in yolov8:: 100%|██████████| 2348/2348 [00:00<00:00, 5749.35it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os
from ultralytics import YOLO

# %%
# model = YOLO('yolov8n.yaml')
# results = model.train(data='/content/Light-Weight-Vehicle-Front-Detec-1/data.yaml', epochs=5)

# %%
# !yolo task=detect mode=predict model='/content/runs/detect/train15/weights/best.pt' conf=0.25 source='/content/gettyimages-621358528-612x612.jpg' save=True

# %%
# infer=YOLO('/content/runs/detect/train15/weights/best.pt')
# infer.predict('/content/gettyimages-621358528-612x612.jpg',save=True,save_txt = True)

# %% [markdown]
# New way trying

# %%
# !yolo task=detect mode=train model='/content/yolov8n.pt' data='/content/T-shirts-detector-1/data.yaml' epochs=20 plots=True
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 24.3MB/s]
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

results_path = './runs/classify/train/results.csv'

results = pd.read_csv(results_path)

plt.figure()
plt.plot(results['epoch'], results['train/loss'], label='train loss')
plt.plot(results['epoch'], results['val/loss'], label='val loss', c='red')
plt.grid()
plt.title('Loss vs epochs')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()


plt.figure()
plt.plot(results['epoch'], results['metrics/accuracy_top1'] * 100)
plt.grid()
plt.title('Validation accuracy vs epochs')
plt.ylabel('accuracy (%)')
plt.xlabel('epochs')

plt.show()

# %%
cm = confusion_matrix(ground_truth_labels, all_predictions)

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=np.unique(ground_truth_labels),
            yticklabels=np.unique(ground_truth_labels))
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# !yolo task=detect mode=predict model='/content/runs/detect/train/weights/best.pt' save_crop=True conf=0.5 source='/content/4423925-hd_1920_1080_25fps.mp4' save=True
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/189) /content/4423925-hd_1920_1080_25fps.mp4: 384x640 1 Shirt, 35.1ms
# video 1/1 (frame 2/189) /content/4423925-hd_1920_1080_25fps.mp4: 384x640 1 Shirt, 9.9ms
# video 1/1 (frame 3/189) /content/4423925-hd_1920_1080_25fps.mp4: 384x640 1 Shirt, 9.5ms
# video 1/1 (frame 4/189) /content/4423925-hd_1920_1080_25fps.mp4: 384x640 1 Shirt, 12.3ms
# video 1/1 (frame 5/189) /content/4423925-hd_1920_1080_25fps.mp4: 384x640 1 Shirt, 9.7ms
# video 1/1 (frame 6/189) /content/4423925-hd_1920_1080_25fps.mp4: 384x640 1 Shirt, 10.0ms
# video 1/1 (frame 7/189) /content/4423925-hd_1920_1080_25fps.mp4: 384x640 1 Shirt, 9.7ms
# video 1/1 (frame 8/189) /content/4423925-hd_1920_1080_25fps.mp4: 384x640 1 Shirt, 10.1ms
# video 1/1 (frame 9/189) /content/4423925-hd_1920_1080_25fps.mp4: 384x640 1 Shirt, 9.0ms
# ...
